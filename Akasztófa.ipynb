# %% [markdown]
# <a href="https://colab.research.google.com/github/near731/X1/blob/main/Akaszt%C3%B3fa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

print("------AKASZTÓFA JÁTÉK------")

szavak=['python','billentyűzet', 'elefánt','állatorvos','hurokáram','megnyúlás','mechatronika','fogászat','intenzitás']

szo=random.choice(szavak)
print("Találd ki a szót!")
print("Irj be egy betűt, hogy megtudd benne van-e a szóban!")

betuk= ''

eletek_szama=15

while eletek_szama>0:
  hiba=0

  for char in szo:
    if char in betuk:
      print(char)

    else:
      print("_")
      hiba+=1

  if hiba==0:
    print("Nyertél :)")
    print("Ez volt a szó: ",szo)
    break

  betu=input("Irj egy betűt: ")

  betuk+=betu
  print("Eddigi betűk:",betuk)

  if betu not in szo:
    eletek_szama-=1
    print("Nincs a szóban ez a betű")
    print("Még",+eletek_szama,"életed maradt.")

    if eletek_szama==0:
      print("Vesztettél!")
# Out:
# ------AKASZTÓFA JÁTÉK------
# Találd ki a szót!
# Irj be egy betűt, hogy megtudd benne van-e a szóban!
# _
# _
# _
# _
# _
# _
# _
# _
# Irj egy betűt: e
# Eddigi betűk: e
# Nincs a szóban ez a betű
# Még 14 életed maradt.
# _
# _
# _
# _
# _
# _
# _
# _
# Irj egy betűt: l
# Eddigi betűk: el
# Nincs a szóban ez a betű
# Még 13 életed maradt.
# _
# _
# _
# _
# _
# _
# _
# _
# Irj egy betűt: m
# Eddigi betűk: elm
# Nincs a szóban ez a betű
# Még 12 életed maradt.
# _
# _
# _
# _
# _
# _
# _
# _
# Irj egy betűt: r
# Eddigi betűk: elmr
# Nincs a szóban ez a betű
# Még 11 életed maradt.
# _
# _
# _
# _
# _
# _
# _
# _
# Irj egy betűt: t
# Eddigi betűk: elmrt
# _
# _
# _
# _
# _
# _
# _
# t
# Irj egy betűt: z
# Eddigi betűk: elmrtz
# _
# _
# _
# _
# _
# z
# _
# t
# Irj egy betűt: s
# Eddigi betűk: elmrtzs
# _
# _
# _
# _
# s
# z
# _
# t
# Irj egy betűt: d
# Eddigi betűk: elmrtzsd
# Nincs a szóban ez a betű
# Még 10 életed maradt.
# _
# _
# _
# _
# s
# z
# _
# t
# Irj egy betűt: p
# ...
